# %% [markdown]
# # Template Matching
#
# The idea is to find a specific section of image (template) on others (bigger that the template).
#
# The template is sweeped over the big image (as inthe 2D convolution), applying an specific matching or comparison equation.
#
# If input image is of size $(W, H)$, and the template is $(w, h)$, the matching image is $(W-w+1, H-h+1)$

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Import image:

# %%
imgFruits = cv2.imread('fruits.jpg',0)
plt.imshow(imgFruits, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Extract template:

# %%
imgKiwi = np.copy(imgFruits[460:600, 545:680])
plt.imshow(imgKiwi, cmap = 'gray', vmin=0, vmax=255)
plt.title('Template'), plt.xticks([]), plt.yticks([])
plt.show()
w, h = imgKiwi.shape[::-1]

# %% [markdown]
# ## Squared difference normalized
#
# \begin{align}
# \large
# R(x,y) = \frac {\sum_{x',y'} (T(x',y') - I(x+x',y+y'))^2} {\sqrt{ \sum_{x',y'} T(x',y')^2 \sum I(x+x',y+y')^2 }}
# \end{align}

# %%
imgFruits1 = imgFruits.copy()
res = cv2.matchTemplate(imgFruits1, imgKiwi, cv2.TM_SQDIFF)
_, _, top_left, _ = cv2.minMaxLoc(res)
bottom_right = (top_left[0] + w, top_left[1] + h)
cv2.rectangle(imgFruits1,top_left, bottom_right, 255, 2)
plt.imshow(res,cmap = 'gray')
plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.imshow(imgFruits1,cmap = 'gray')
plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Squared difference
#
# \begin{align}
# \large
# R(x,y) = \sum_{x',y'} (T(x',y') - I(x+x',y+y'))^2
# \end{align}

# %%
imgFruits1 = imgFruits.copy()
res = cv2.matchTemplate(imgFruits1, imgKiwi, cv2.TM_SQDIFF)
_, _, top_left, _ = cv2.minMaxLoc(res)
bottom_right = (top_left[0] + w, top_left[1] + h)
cv2.rectangle(imgFruits1,top_left, bottom_right, 255, 2)
plt.imshow(res,cmap = 'gray')
plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.imshow(imgFruits1,cmap = 'gray')
plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
plt.show()
